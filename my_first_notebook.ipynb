# %% [markdown]
# **What is the difference between hardware and software? Give one example of each.**
#
#
# **Hardware**: Hardware is physical parts of a computer. We can see, touch and feel it
#
# **Example:** Keyboard, CPU, Display
#
# **Software:** Software is programs or instructions that run on a computer. You cannot touch it
#
# **Example:** Operating Systems Like Window and Linux
#
# So the Hardware is physical thing and Software is a program that run on hardware
